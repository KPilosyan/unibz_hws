# %%
import gensim

# %%
import csv 

pages_dict={}

with open('Lab Corpus') as index_file:                                                                                          
    index_list = csv.reader(index_file, delimiter='\t')
    for index in index_list:
        if index:
            print(index)
        #pages_dict[int(index[1])]={"url":index[0],"degree":0,"destinations":[]}
        
print(pages_dict)
# Out:
# [',"x"']
# ['1,"No-code data science is easier than you think.  Learn how to start building models in minutes at our 3-day conference — completely free."']
# ['2,"@Mikeyanlam @ARKInvest @richard_chu97 @Soumyazen @TerraPharma1 Teladoc before livongo acquisition is just zoom doctor. That business have a lot competition, everybody think they can do it, Amazon, Walmart etc. However, Livongo changes the picture since there’s data science part not so easy to replicate. It’s dead money until livongo pick up."']
# ['3,"@niajmattu @RachelBitecofer @Davidj2040 @EvanMcMullin Because beyond that they don’t agree on anything. People think the aversion to data science and fact is a far right thing. It’s just a general right thing."']
# ['4,"@blairnilsson BLAIR!! thank you. I will check the dates and see what i can spin up. I\'m more data science than data sec *right* now but I also think I\'d love to see what the community is up to!"']
# ['5,"@RoshenSethna @Jan_Ainali @ryanko @NavaPBC @MakaelaStephens @ohlookitseric @AliaTB @codeforamerica @exygy @publiccodenet @MMazanec22 @ruthiereisner This is something we think deeply about when we apply technology to criminal justice reform efforts: understanding the unintended consequences of it\'s use.  And another reason why clear data science and software ethic statements are so important."']
# ['6,"@MehNitesh2 @JoTrader4 @WholeMarsBlog Data will be provided at the discretions of  company to whom they think is appropriate to be provided. Those who think its not 10x can prove by generating their own data. I am into Data Science too, but I don\'t need data to understand.."']
# ['7,"Feel free to comment, we did love to hear your thoughts!']
# ['Which of these do you think is most emerging in the domain of Data Science?']
# ['#DataScience #AI #ML #polltime #DSDojo"']
# ['8,"Feel free to comment, we did love to hear your thoughts!']
# ['Which of these do you think is most emerging in the domain of Data Science?']
# ['#DataScience #AI #ML #polltime #DSDojo"']
# ['9,"No-code data science is easier than you think.  Learn how to start building models in minutes at our 3-day conference — completely free."']
# ['10,"Probably unpopular opinion, but I think it’s great. Basic stats and data science is probably more broadly relevant than calculus these days. Plus it sounds refreshing, and if done well, it will make school much more fun and help with data literacy :) https://t.co/N5jBadxW5O"']
# ['11,"Model creation and deployment doesn’t need to be so difficult! Find out why your peers think we’re the best software for citizen data scientists. https://t.co/JzthaQ4AJI https://t.co/LSO0RS4Ec0"']
# ['12,"Thinking about learning AI, I came across a doubt that is the title of this article. The world of development is changing rapidly and I think I could catch that wave. How about you?✨ #artificialintelliegence #machinelearning #datascience https://t.co/s6A5XOrbe7 https://t.co/Ae4n5izvuy"']
# ['13,"Thinking about learning AI, I came across a doubt that is the title of this article. The world of development is changing rapidly and I think I could catch that wave. How about you?✨ #artificialintelliegence #machinelearning #datascience https://t.co/s6A5XOrbe7 https://t.co/Ae4n5izvuy"']
# ['14,"@GeorgeBowling82 @OldMackIsBack @toadmeister @cjsnowdon @whippletom @atomicallyblond @theJeremyVine @DAaronovitch @fascinatorfun @TimBushLondon @BottomleyFiona @BouvierJourno @Bobforster15 @nemophilic @JimTimberthing @ParkinJim @andrew_croxford @jneill @Clairina ... where is THIS evidence? You need to cite it.']
# ['Puritan?']
# ['Yes, I do think your analysis is incomplete, I am holding you to a higher standard of Data Science.']
# ["A bit like mine, which isn't threadbare, and shows mobility is highly correlated to infection."]
# ['https://t.co/lOZ1hlQTdi"']
# ['15,"Is it ever too early to start learning about data science? We don’t think so, and that’s why we’re so excited to see an ebook for kids to start grasping the core concepts! #datascience https://t.co/EFq9yF0D1t"']
# ['16,"Is it ever too early to start learning about data science? We don’t think so, and that’s why we’re so excited to see an ebook for kids to start grasping the core concepts! #datascience https://t.co/EFq9yF0D1t"']
# ['17,"@elerianm I would think that it is Fiscal policy that is suppposed to show “compassion” like open mindedness…the Federal Reserve is supposed to follow the data (science)??"']
# ['18,"Definitions: Data science is ""The use of analytical and computational techniques to extract meaning from novel data sources usually for the sake of supporting organisational decision making"" -&gt; I like this definition, going to think of how to distil it down for easier use myself"']
# ['19,"@NorthernLady6 @nikkiraqs @Elescorial3 I am trained in data science but you don\'t need to be to understand a graph. How can you compare September? No one was vaccinated last September as you well know. If you don\'t think the vaccine works on variants then that is contradicting all scientists who have stated it does."']
# ['20,"Want to learn how to think like a data scientist? Take our Data Science for Everyone course this summer. Deadline to apply is May 27 for NYU students and May 12 for non-NYU students. Visit our website to apply! https://t.co/3A7qsM1Oy0"']
# ['21,"@helenhamill @nird Agree. There\'s also a neg impact on rights with measures adopted in a health crisis. If more people understood importance of public health &amp; stopped listening to those who think they understand data/science, FB cranks there would be less need to ‘have to‘ stop people causing risk"']
# ['22,"@helenhamill @nird Agree. There\'s also a neg impact on rights with measures adopted in a health crisis. If more people understood importance of public health &amp; stopped listening to those who think they understand data/science, FB cranks there would be less need to ‘have to‘ stop people causing risk"']
# ['23,"Model creation and deployment doesn’t need to be so difficult! Find out why your peers think we’re the best software for citizen data scientists. https://t.co/JzthaQ4AJI https://t.co/LSO0RS4Ec0"']
# ['24,"#DataScience is the hottest career out there in the IT industry. But everybody is doing it, do you think it is the best for you? To know more about Data Science. ']
# ['Register for the webinar now https://t.co/sBLpOnyFIv']
# ['#datasciencetraining #Edureka #RidiculouslyCommitted https://t.co/9jCIjLfbUL"']
# ['25,"Think Like a Data Scientist: Tackle the data science process step-by-step #DataScience https://t.co/Ea7yTyk8D7"']
# ['26,"Think Like a Data Scientist: Tackle the data science process step-by-step #DataScience https://t.co/Us6CNsmlfu"']
# ['27,"Another one for @data_science_ie to think about. The moment of measurement is sometimes lost in the world of bigger, better (?) data. Truth matters - and can’t be found in the spreadsheet (or dataset) alone. https://t.co/tgGJuS8rgu"']
# ['28,"#DataScience is the hottest career out there in the IT industry. But everybody is doing it, do you think it is the best for you? To know more about Data Science. ']
# ['Register for the webinar now https://t.co/sBLpOnyFIv']
# ['#datasciencetraining #Edureka #RidiculouslyCommitted https://t.co/9jCIjLfbUL"']
# ['29,"Two projects due tomorrow at 8am, and then there’s just one left. I’m so ready for this semester to be over! I think as a treat for making it, I’ll purchase a handful of fun data science t-shirts so I can code in style."']
# ['30,"#DataScience is the hottest career out there in the IT industry. But everybody is doing it, do you think it is the best for you? To know more about Data Science. ']
# ['Register for the webinar now https://t.co/sBLpOnyFIv']
# ['#datasciencetraining #Edureka #RidiculouslyCommitted https://t.co/9jCIjLfbUL"']
# ['31,"#DataScience is the hottest career out there in the IT industry. But everybody is doing it, do you think it is the best for you? To know more about Data Science. ']
# ['Register for the webinar now https://t.co/sBLpOnyFIv']
# ['#datasciencetraining #Edureka #RidiculouslyCommitted https://t.co/9jCIjLfbUL"']
# ['32,"#DataScience is the hottest career out there in the IT industry. But everybody is doing it, do you think it is the best for you? To know more about Data Science. ']
# ['Register for the webinar now https://t.co/sBLpOnyFIv']
# ['#datasciencetraining #Edureka #RidiculouslyCommitted https://t.co/9jCIjLfbUL"']
# ['33,"Authenticity in data science up next. Answering what is trust? = authenticity = consumer confidence = we don’t think about it enough #Gitaucon #bnts https://t.co/Kgc2czt3UU"']
# ['34,"Authenticity in data science up next. Answering what is trust? = authenticity = consumer confidence = we don’t think about it enough #Gitaucon #bnts https://t.co/Kgc2czt3UU"']
# ['35,"RT: DataScienceCtrl No-code data science is easier than you think.  Learn how to build models in minutes at #AlteryxInspire. https://t.co/WeEvhddhCb https://t.co/wHVpkrUpjJ"']
# ['36,"No-code data science is easier than you think.  Learn how to build models in minutes at #AlteryxInspire. https://t.co/8PnRkwDr5n https://t.co/0lI9OkgRtp"']
# ['37,"No-code data science is easier than you think.  Learn how to build models in minutes at #AlteryxInspire. https://t.co/OBklTRvjwn https://t.co/gerfEPBDPv"']
# ['38,"@NHSouthernGirl @JimmyJunkCoin @DebbieSVA @GOPChairwoman I think we are starting to get that u are a doctor.   I sell software so data is a big deal.  We call it data science so show us your science on texas covid since March 2021 please doctor."']
# ['39,"@lintool I totally agree with this, but I am not sure ""data science == data cleaning/processing"", b/c data science includes modeling. So people can think they do/teach DS without teaching/doing data processing."']
# ['40,"@HeavyGrenadier I think econometrics or stats pairs best here. Because those outputs are meant to be looked at by a human. Software engineering style data science less so."']
# ['41,"This summer,1st yr #Otterbein students will be reading ""Factfulness: Ten Reasons We’re Wrong About the World–and Why Things Are Better Than You Think,"" a non-fiction book about data science.']
# [' #OtterbeinCommonBook #CommonBook #summerreading #factfulness']
# ['https://t.co/fKBxbkIKeF https://t.co/LhfgWSKt3H"']
# ['42,"@HeyladyJami @JAXenterCOM what year was #data #science was created as a #job i personally think the person should get 20% compensation for using their data"']
# ['43,"@nadindadev In my case it was ""learn a thing that people think you have to be really smart to understand, whether or not that\'s true"". In my case, that was functional programming. A few years later the hot ticket seemed to be data science. Right now it still seems to be machine learning."']
# ['44,"Want to learn how to think like a data scientist? Take our Data Science for Everyone course this summer. Deadline to apply is May 27 for NYU students and May 12 for non-NYU students. Visit our website to apply! https://t.co/3A7qsM1Oy0"']
# ['45,"This summer,1st yr #Otterbein students will be reading ""Factfulness: Ten Reasons We’re Wrong About the World–and Why Things Are Better Than You Think,"" a non-fiction book about data science.']
# [' #OtterbeinCommonBook #CommonBook #summerreading #factfulness']
# ['https://t.co/fKBxbkIKeF https://t.co/LhfgWSKt3H"']
# ['46,"@samayanissanke @_nikhef Just out of interest: would people who left academia 8yrs ago, with zero scientific achievements since then, but lots of real world data science experience even stand a chance, you think? Asking for a friend, obviously."']
# ['47,"@geomblog I don’t think in most big name pubs even the journalist writing the story can directly control the headline. Copy editors and data science is usually responsible."']
# ['48,"Title: Good Data Scientist, Bad Data Scientist']
# ['💬: ""Data Scientist"" is a pretty good language to describe data. I think this is a fair title in terms of how to write a data scientist. The term is ambiguous but as the article points out you don\'t need to do a data science…"']
# ['49,"Model creation and deployment doesn’t need to be so difficult! Find out why your peers think we’re the best software for citizen data scientists. https://t.co/JzthaQ4AJI https://t.co/LSO0RS4Ec0"']
# ['50,"I think PyCaret is going to be the next sklearn for ML and data science in Python."']
# ['51,"@blenster @integgroll @K3n_5s @bink I didn\'t think I had a favorite until I worked in Python for data science for a year and then got a job that wanted me to work in C#. All I want is to go back to Python... :("']
# ['52,"@blenster @integgroll @K3n_5s @bink I didn\'t think I had a favorite until I worked in Python for data science for a year and then got a job that wanted me to work in C#. All I want is to go back to Python... :("']
# ['53,"@DynamicWebPaige @JoshGhalgh i agree with you both haha. I think Jupyter Lab is in the same category as RStudio etc, though i don\'t think I\'d call it an IDE, maybe an IDSE (integrated data science environment). I think it\'s worth emphasizing the order of priorities to be DS first, developing second"']
# ['54,"@DynamicWebPaige @JoshGhalgh i agree with you both haha. I think Jupyter Lab is in the same category as RStudio etc, though i don\'t think I\'d call it an IDE, maybe an IDSE (integrated data science environment). I think it\'s worth emphasizing the order of priorities to be DS first, developing second"']
# ['55,"Model creation and deployment doesn’t need to be so difficult! Find out why your peers think we’re the best software for citizen data scientists. https://t.co/JzthaQ4AJI https://t.co/LSO0RS4Ec0"']
# ['56,"@tweet_dispencer I think the display was a one-off demonstration, but it was this Observatory:']
# ['https://t.co/DuPxQKr3Rq"']
# ['57,"#AI Gets the Glory but ML is Quietly Making Fortunes']
# ['When we think about the future of #data #science, it’s easy to get carried away. For a couple of decades now, if you bel ..']
# ['https://t.co/Mggu8vKXUN https://t.co/VuCYw7jXLf"']
# ['58,"No-code data science is easier than you think.  Learn how to start building models in minutes at our 3-day conference — completely free."']
# ['59,"Another one for @data_science_ie to think about. The moment of measurement is sometimes lost in the world of bigger, better (?) data. Truth matters - and can’t be found in the spreadsheet (or dataset) alone. https://t.co/tgGJuS8rgu"']
# ['60,"UP students,if you do internal transfer,do you transfer to first year of that degree? Because I don’t think I want to transfer to second year of data science..."']
# ['61,"As the Harvard Business Review recognised back in 2014, #data science is the new ‘sexy’ role on the block.']
# ['So when should you think about hiring a Data Scientist for your business? https://t.co/C11HomN7e3 https://t.co/XTiVotLUr3"']
# ['62,"Another one for @data_science_ie to think about. The moment of measurement is sometimes lost in the world of bigger, better (?) data. Truth matters - and can’t be found in the spreadsheet (or dataset) alone. https://t.co/tgGJuS8rgu"']
# ['63,"@jbminn @ariadneconill @QuinnyPig P.S., if these types of complex systems are an area of interest for you or someone you know, we\'re hiring ⬇️…']
# ["While I don't think that data science can be a control (and has to be used carefully to avoid amplifying inequity) I think might shine a light."]
# ['https://t.co/hr2hbVZp9K"']
# ['64,"@WillsBossyMom @politicalwilli So many people say of sports analysts ""You think you know everything"" but data science has taught me so much about uncertainty and now I see how so many people are certain of things there is no evidence for."']
# ['65,"@TheTradeLawGuy @DrJacobsRad I understand your point that it cuts back on hospitalization and death but do we know where are we heading? There’s no data/science to support that. Watch Dr. Faucci’s segment and think how we can have real world data when there’s no other country had done what we are doing. https://t.co/oAvg5ZHcdo"']
# ['66,"Think Like a Data Scientist: Tackle the data science process step-by-step #DataScience https://t.co/Ea7yTyk8D7"']
# ['67,"Think Like a Data Scientist: Tackle the data science process step-by-step #DataScience https://t.co/9WcI73Qtnr"']
# ['68,"Think Like a Data Scientist: Tackle the data science process step-by-step #DataScience https://t.co/Ea7yTyk8D7"']
# ['69,"Think Like a Data Scientist: Tackle the data science process step-by-step #DataScience https://t.co/Ea7yTyk8D7"']
# ['70,"Think Like a Data Scientist: Tackle the data science process step-by-step #DataScience https://t.co/9WcI73Qtnr"']
# ['71,"Last week on our DSaaS series, we looked at data science as a service. Let us know what you think it is? You can also head on to our #Instagram @emerge_iq or #LinkedIn #EMERGEiQ to find out! ']
# ['#DataScience #data #MachineLearning #ArtificialIntelligence #future"']
# ['72,"Think Like a Data Scientist: Tackle the data science process step-by-step #DataScience https://t.co/9WcI73Qtnr"']
# ['73,"No-code data science is easier than you think.  Learn how to start building models in minutes at our 3-day conference — completely free."']
# ['74,"If you want to be in data science, or in tech, where you live actually matters.']
# ["It's not the only thing that matters, but you need to think about the optimal city that will give you the most opportunity."]
# ['#datascience #technology https://t.co/41eGrdRm2Z"']
# ['75,"@Kathryn92796178 @palliddh @hartgroup_org @vetrissimo what evidence? Anecdotal? ""I sat next to a vaxxed person and now I\'m late for my period"", however amusing. is not good data. Science is not progressed by rumour...otherwise we\'d all still think the earth was flat."']
# ['76,"@HussainiMaina_ @NumFOCUS @PyData @matplotlib @numpy_team @NASA Sorry, you don\'t think the Numpy team get recognition? It\'s one of the most instantly recognisable libraries in all of programming if not just Data Science..."']
# ['77,"@Kathryn92796178 @palliddh @hartgroup_org @vetrissimo what evidence? Anecdotal? ""I sat next to a vaxxed person and now I\'m late for my period"", however amusing. is not good data. Science is not progressed by rumour...otherwise we\'d all still think the earth was flat."']
# ['78,"I\'m mentoring a college student who\'s an econ major uncertain about her career direction. I think she needs to talk to folks w/ eco degrees who have non-Wall-Streetish jobs. Data science/analysis, behavioural research stuff, etc. Anyone wanna volunteer or make a connection?"']
# ['79,"I\'m mentoring a college student who\'s an econ major uncertain about her career direction. I think she needs to talk to folks w/ eco degrees who have non-Wall-Streetish jobs. Data science/analysis, behavioural research stuff, etc. Anyone wanna volunteer or make a connection?"']
# ['80,"I\'m mentoring a college student who\'s an econ major uncertain about her career direction. I think she needs to talk to folks w/ eco degrees who have non-Wall-Streetish jobs. Data science/analysis, behavioural research stuff, etc. Anyone wanna volunteer or make a connection?"']
# ['81,"@KevinColePFF I’ll definitely be a listener going forward, I’ve been reading a lot more data science articles on PFF and it’s fascinating stuff, the name Unexpected Points is good but I think your podcast might benefit from having more of a clear identity that people will click for"']
# ['82,"@rctatman Oh wow, #4 really strikes a cord.']
# ['I agree with you, but I need to mull over a possible alternative vocab word.']
# ['I joke that we aren\'t the data science team, we\'re the smart team that solves difficult/ impossible problems.  (We do ds and de) . Will need to think of short word alts."']
# ['83,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['84,"Last week on our DSaaS series, we looked at data science as a service. Let us know what you think it is? You can also head on to our #Instagram @emerge_iq or #LinkedIn #EMERGEiQ to find out! ']
# ['#DataScience #data #MachineLearning #ArtificialIntelligence #future"']
# ['85,"@achalaugustine @makkenmac @AlecStapp Gosh, so love being mansplained to about science. As it happens, when you do this type of data comparisons, your first key comparison is to ""most similar"" entities. If you don\'t think so, tell me what your data science or biostat credentials are."']
# ['86,"data science is weird, sure that being corrected means more as functional statistic of your slow pace in learning than it does your open-mindedness. this i think is also why ai &amp; machine learning are so important to finesse accuracy out of hard to separate concepts in e-learning"']
# ['87,"@nntaleb Would also be interesting if you give a general overview on your thoughts about the differences between data science, statistics, machine learning and AI. Or if you think the difference between these terms is meaningless and marketing-driven."']
# ['88,"#NCDSMemberSpotlight: “Data science is integrated in subject matter and research programs across all 10 NC State colleges and is part of our think and do mindset. At @NCState, we believe #datascience is for everyone.” @NCState_DSI https://t.co/AxgUJv4ikZ"']
# ['89,"#AI Gets the Glory but ML is Quietly Making Fortunes']
# ['When we think about the future of #data #science, it’s easy to get carried away. For a couple of decades now, if you bel ..']
# ['https://t.co/Mggu8vKXUN https://t.co/VuCYw7jXLf"']
# ['90,"@OnFireAnders insert existential crisis here... i’m a data science student with hopes of working on emerging AI/ML technology like this... i always think you would still consciously be aware of entering a VR world even w/ insane detail, and no matter how long you’ve been in/on the VR world"']
# ['91,"#DataScience ']
# ['Data science is wide rang of spectrum let\'s commit explorer always to achieve goal...What do you think about and your point of is it valid opinian 👍 https://t.co/FGbcue1eE8"']
# ['92,"#DataScience ']
# ['Data science is wide rang of spectrum let\'s commit explorer always to achieve goal...What do you think about and your point of is it valid opinian 👍 https://t.co/FGbcue1eE8"']
# ['93,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['94,"No-code data science is easier than you think.  Learn how to start building models in minutes at our 3-day conference — completely free."']
# ['95,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['96,"I think I\'ll use this for NPA Data Science... 🤷\u200d♂️ https://t.co/bsiHVyxjqF"']
# ['97,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['98,"@simonfa @chrispyking2 @barryonthefly @Mark_J_Perry @CHSommers You think poor people are unintelligent? Wow!']
# ['I lived in a caravan until I was 17 in abject poverty, I tried hard at college having gotten no where in school, eventually I got through university gaining a MSc in Computer Science. I now run the Data Science group in my workplace."']
# ['99,"@TewksHitting You’d think an academically esteemed institute would value measurable &amp; actionable data that can be used to make more precise decision on player &amp; program development. If nothing else data science students could use the information to further real world education &amp; experience"']
# ['100,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['101,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['102,"Probably unpopular opinion, but I think it’s great. Basic stats and data science is probably more broadly relevant than calculus these days. Plus it sounds refreshing, and if done well, it will make school much more fun and help with data literacy :) https://t.co/N5jBadxW5O"']
# ['103,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['104,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['105,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['106,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['107,"New cover idea for Elements of Data Science.']
# ['https://t.co/THmMVDGwks']
# ['(The cover wraps, so the left half is the back and the right half is the front)']
# ['What do we think? https://t.co/4WqIeV8Jup"']
# ['108,"If you want to learn more about what I do at @Zymergen and how we think about data science, see our new blog post! If it sounds interesting, we’re hiring! https://t.co/RhJoR8cNze"']
# ['109,"@pankaj @lintool @aneeshs @squarecog I think the novelty effect wore off years ago. Now sentiment-analysis-on-tweets is homework #2 in beginner data science curriculum, just after intro-to-pandas"']
# ['110,"Very excited to see @InmonBill at @Data_AI_Summit! Data architecture is more important than ever and it will be exciting to hear how to think about it for modern challenges including data science, massive unstructured datasets, and cloud environments. https://t.co/GM1uOzJEeG"']
# ['111,"@nathanbroon Indeed. I think this is true for the process of science as a whole (and what it\'s what I like about it). In data science the iterations just come at a faster rate compared to other fields."']
# ['112,"@skepteis I’ll go off on one on this. I think our exploratory and interactive data science indirectly gives us the answers we want by iteratively refining and changing our questions of the data. We don’t really know what we want when we start."']
# ['113,"@Iyervval Finding relevant data from such a huge data set is a challenge even for a trained statistician or data scientist.']
# ['If some journalists think they can easily come out with statistics, govt and big IT should be shutting down all data science departments.']
# ['n/n"']
# ['114,"@brianros1 @Tommers71 Understandable. But I do think there’s a difference between ignoring data/science and ignoring bureaucratic “experts”.']
# ['Unfortunately, those very experts ignore the data and science themselves for political reasons. EG, the CDC summer camp guidances and school openings."']
# ['115,"@DrAnneCarpenter @markowetzlab I think part of the problem is that computational biology /bioinformatics has no academic home. It was chopped up between biology, computer science, stats, applied math, physics or even more recently stats -&gt; data science !  Without Dept of Comp Biol, it lacks identity."']
# ['116,"@SouadH9 @kareem_carr Yea I understand a lot of data science don\'t feel the benefits by learning more comp sci. I reject this because what I end up seeing a lot are folks who see everything as tables, who write inefficient algos to retrieve data, use memory and don\'t really think about concurrency..."']
# ['117,"So why do #DataScientists think that stats is dead?']
# ['Where does the notion that there is no longer any need for #statisticalanalysis come from?']
# ['And are they right?']
# ['https://t.co/gBcPivkSTO https://t.co/m44QjhhCQw"']
# ['118,"Why do #DataScientists think that #stats is dead?']
# ['https://t.co/gBcPivkSTO https://t.co/fEJYuS5L7i"']
# ['119,"I think PyCaret is going to be the next sklearn for ML and data science in Python."']
# ['120,"Very excited to see @InmonBill at @Data_AI_Summit! Data architecture is more important than ever and it will be exciting to hear how to think about it for modern challenges including data science, massive unstructured datasets, and cloud environments. https://t.co/GM1uOzJEeG"']
# ['121,"Very excited to see @InmonBill at @Data_AI_Summit! Data architecture is more important than ever and it will be exciting to hear how to think about it for modern challenges including data science, massive unstructured datasets, and cloud environments. https://t.co/GM1uOzJEeG"']
# ['122,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['123,"@JackPosobiec of course. there are so many woke think tanks on the left, you can be sure everything that comes out of a dem\'s mouth or a journalist\'s keyboard is the result of woke partisan data science."']
# ['124,"Probably unpopular opinion, but I think it’s great. Basic stats and data science is probably more broadly relevant than calculus these days. Plus it sounds refreshing, and if done well, it will make school much more fun and help with data literacy :) https://t.co/N5jBadxW5O"']
# ['125,"@PutOnUrMask You are intellectual by the way you look and think about things. The way you deal with stuff and being smart about your ideology. This is how to be a proper intellectual. ']
# ['To show people that you are intellectual, just read up on things that are in. For example: data science...."']
# ['126,"@0K_ultra And frankly — in many many cases, the math is simpler than people are willing to admit. ']
# ['People want to position their value-add as automagic ""data-science"" because they think it sounds good. 🤷\u200d♀️"']
# ['127,"EASY PATH. On this path, you will get lots of practical skills but only an intuitive sense of the theory. I think the easiest way to start is to read a good data science book and get your hands dirty. I like to recommend ""R for Data Science"" for that. https://t.co/BlHcAOsxJX"']
# ['128,"Think Like a Data Scientist: Tackle the data science process step-by-step #DataScience https://t.co/Us6CNsmlfu"']
# ['129,"6/n']
# ['I think you can improve majoring in Econ with a second major in something like statistics (get data science too) or psychology (double down on marketing. You can also do Econ/CS if you’re really ambitious."']
# ['130,"@gosensgo101 GREAT POINT. We thought it was hunger games for the first dose? Imagine this non data/ science gov rolling out second doses when they think “ah people are 85% protected, just send shit wherever”"']
# ['131,"Now that Grasshopper is running on the web, I\'d love to see someone take this interface and apply it to domains outside architecture. It\'s such a fun way to code. I think fields like data-science could really benefit from a more friendly on-ramp."']
# ['132,"Now that Grasshopper is running on the web, I\'d love to see someone take this interface and apply it to domains outside architecture. It\'s such a fun way to code. I think fields like data-science could really benefit from a more friendly on-ramp."']
# ['133,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['134,"\'Don’t let anybody else impose on you what they think you’re capable of and what’s the best looking life and career for you.\' This week\'s #JazzShaper guest is co-founder of data science company @dunnhumby, @Edwina_Dunn. https://t.co/QanxiKUGLy"']
# ['135,"EASY PATH. On this path, you will get lots of practical skills but only an intuitive sense of the theory. I think the easiest way to start is to read a good data science book and get your hands dirty. I like to recommend ""R for Data Science"" for that. https://t.co/BlHcAOsxJX"']
# ['136,"If you want to learn more about what I do at @Zymergen and how we think about data science, see our new blog post! If it sounds interesting, we’re hiring! https://t.co/RhJoR8cNze"']
# ['137,"@Brgut2 There are many doctors and scientists not in charge of covid in BC, too. Why do you assume ""thousands of social media people"" are not scientifically literate enough to parse data? Science isn\'t based on what you ""think"", it\'s based on data. That they\'ve been hiding."']
# ['138,"Whenever I try to picture what an accurate movie star hacker would look like today, all I can think of is a data science engineer that got bored with too much free time 🤔"']
# ['139,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['140,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['141,"Just quit my job to focus on trading and data science. Lowkey feeling some pressure but I think this is the best risk I\'ll take my whole life."']
# ['142,"You can prob tell that I’m bullish on experimentation. Truthfully, I think experimentation is the clearest path to ROI for data science teams. However, increasing experiment velocity while maintaining rigor is hard. Great read from @chesharma87 on the challenge and opportunity. https://t.co/RdCSZMXgAr"']
# ['143,"If you want to learn more about what I do at @Zymergen and how we think about data science, see our new blog post! If it sounds interesting, we’re hiring! https://t.co/RhJoR8cNze"']
# ['144,"The pandemic exposed the need to think about tomorrow’s supply chains. How do we create resiliency and agility in the digital age? I love this explanation from @NelsonPetracek, @TIBCO CTO, who says the answer lies with data science and digital twins']
# ['https://t.co/9t1p1pDO8z"']
# ['145,"If you want to learn more about what I do at @Zymergen and how we think about data science, see our new blog post! If it sounds interesting, we’re hiring! https://t.co/RhJoR8cNze"']
# ['146,"If you want to learn more about what I do at @Zymergen and how we think about data science, see our new blog post! If it sounds interesting, we’re hiring! https://t.co/RhJoR8cNze"']
# ['147,"A full time opportunity in sports analytics is rare, and it certainly takes luck and patience to find the right fit. So I think it\'s worth celebrating the wins where we get them. That being said, happy to announce I\'ll soon be joining the data science team at @swishanalytics 🏀"']
# ['148,"This hurts to say as a data science person, but I think 17lands is a net negative for limited *on its own terms*. Many have argued that it’s bad b/c players use the data wrong, but I think it’ll be worse once the formulas are ironed out and people use the data correctly."']
# ['149,"A full time opportunity in sports analytics is rare, and it certainly takes luck and patience to find the right fit. So I think it\'s worth celebrating the wins where we get them. That being said, happy to announce I\'ll soon be joining the data science team at @swishanalytics 🏀"']
# ['150,"EASY PATH. On this path, you will get lots of practical skills but only an intuitive sense of the theory. I think the easiest way to start is to read a good data science book and get your hands dirty. I like to recommend ""R for Data Science"" for that. https://t.co/BlHcAOsxJX"']
# ['151,"EASY PATH. On this path, you will get lots of practical skills but only an intuitive sense of the theory. I think the easiest way to start is to read a good data science book and get your hands dirty. I like to recommend ""R for Data Science"" for that. https://t.co/BlHcAOsxJX"']
# ['152,"EASY PATH. On this path, you will get lots of practical skills but only an intuitive sense of the theory. I think the easiest way to start is to read a good data science book and get your hands dirty. I like to recommend ""R for Data Science"" for that. https://t.co/BlHcAOsxJX"']
# ['153,"@KarlMuth @economeager Many people are concerned but I personally think it\'s great. It gives people highly marketable work experience in data science. It reduces the share who enter a PhD and realize after 2 years of class work that they hate the research part. And unlike an MA, it\'s paid."']
# ['154,"EASY PATH. On this path, you will get lots of practical skills but only an intuitive sense of the theory. I think the easiest way to start is to read a good data science book and get your hands dirty. I like to recommend ""R for Data Science"" for that. https://t.co/BlHcAOsxJX"']
# ['155,"A full time opportunity in sports analytics is rare, and it certainly takes luck and patience to find the right fit. So I think it\'s worth celebrating the wins where we get them. That being said, happy to announce I\'ll soon be joining the data science team at @swishanalytics 🏀"']
# ['156,"A full time opportunity in sports analytics is rare, and it certainly takes luck and patience to find the right fit. So I think it\'s worth celebrating the wins where we get them. That being said, happy to announce I\'ll soon be joining the data science team at @swishanalytics 🏀"']
# ['157,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['158,"A full time opportunity in sports analytics is rare, and it certainly takes luck and patience to find the right fit. So I think it\'s worth celebrating the wins where we get them. That being said, happy to announce I\'ll soon be joining the data science team at @swishanalytics 🏀"']
# ['159,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['160,"A full time opportunity in sports analytics is rare, and it certainly takes luck and patience to find the right fit. So I think it\'s worth celebrating the wins where we get them. That being said, happy to announce I\'ll soon be joining the data science team at @swishanalytics 🏀"']
# ['161,"According to the ads I’m seeing, Twitter thinks I should get a masters in data science and download apps to buy dogecoin. I’m not even kidding. ']
# ['I think I’ve finally officially made it to tech twitter, guys."']
# ['162,"Probably unpopular opinion, but I think it’s great. Basic stats and data science is probably more broadly relevant than calculus these days. Plus it sounds refreshing, and if done well, it will make school much more fun and help with data literacy :) https://t.co/N5jBadxW5O"']
# ['163,"A full time opportunity in sports analytics is rare, and it certainly takes luck and patience to find the right fit. So I think it\'s worth celebrating the wins where we get them. That being said, happy to announce I\'ll soon be joining the data science team at @swishanalytics 🏀"']
# ['164,"A full time opportunity in sports analytics is rare, and it certainly takes luck and patience to find the right fit. So I think it\'s worth celebrating the wins where we get them. That being said, happy to announce I\'ll soon be joining the data science team at @swishanalytics 🏀"']
# ['165,"I think \'Data Science and Renewable Energy\' is an undiscovered Gold mine.']
# ['Analyzing cost, expenditure, gaseous emission and revenue generation.']
# ['Data correlation and forcasting using pictorial/chart representation']
# ["Being 'technically' sound."]
# ['STEM full package"']
# ['166,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['167,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['168,"This hurts to say as a data science person, but I think 17lands is a net negative for limited *on its own terms*. Many have argued that it’s bad b/c players use the data wrong, but I think it’ll be worse once the formulas are ironed out and people use the data correctly."']
# ['169,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['170,"Respected sir, i am one of your student from trinity bhopal current pursuing PhD in data science (cse). Sir i think we need a political reforms so we could insure the accountability, confidentiality and authorization of system. https://t.co/wdY5tklFMM"']
# ['171,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['172,"Librarians who support Data Science: What information literacy / scholarly communication / information landscape topics broadly defined do you think masters students need to know? Both while they are in their program but also after they graduate?"']
# ['173,"@hjpimentel The problem is that we often times don\'t understand the underlying biological process, or worse, we think we know and we don\'t. I do think that feature engineering in biological data science is really inescapable and that requires, to some degree, a theory of the data generation."']
# ['174,"EASY PATH. On this path, you will get lots of practical skills but only an intuitive sense of the theory. I think the easiest way to start is to read a good data science book and get your hands dirty. I like to recommend ""R for Data Science"" for that. https://t.co/BlHcAOsxJX"']
# ['175,"EASY PATH. On this path, you will get lots of practical skills but only an intuitive sense of the theory. I think the easiest way to start is to read a good data science book and get your hands dirty. I like to recommend ""R for Data Science"" for that. https://t.co/BlHcAOsxJX"']
# ['176,"I\'ve now spoken to multiple college students who studied CS/eng and are trying to decide between software engineering and data science. ']
# ['I think people know SWE work is highly valued by industry, but data work might be more interesting as a career, hence the dilemma 🤔"']
# ['177,"@ThomasMailund It is thicker than your rest of the books I have. I think Beginning Data Science with R is thicker. Love your writing and it is strange that I like R and C programming both. Will definitely buy this."']
# ['178,"@TomOHanlon17 @carvillshill @DavQuinn Yes I’ve seen him call out a few things.']
# ['I think they could be working in tandem with @MlMcNamaraTD and calling out the government to provide the data/science behind these devastating lockdowns."']
# ['179,"What you think you’ll be asked to do at work after a Data Science degree: “build a model with this data to predict x”']
# ['Reality...']
# ['Them: “I want our department to use ML”']
# ['DS: “Is there a particular problem &amp; dataset?”']
# ['Them: “You’re the expert. Find out”']
# ['(1/2)"']
# ['180,"What you think you’ll be asked to do at work after a Data Science degree: “build a model with this data to predict x”']
# ['Reality...']
# ['Them: “I want our department to use ML”']
# ['DS: “Is there a particular problem &amp; dataset?”']
# ['Them: “You’re the expert. Find out”']
# ['(1/2)"']
# ['181,"@AmeliaMN @mhkingsbury @uclaIDS Cool. Maybe this summer I’ll do some investigating. I don’t think there’s any reason high why high school students with a little bit of math background couldn’t do the data science course I currently teach at Mac, esp. if it were taught over a whole year."']
# ['182,"@AmeliaMN I’d love to see some effort at this in MN. In SPPS, no high schools appear to offer Data Science. I think a great place to start would be at high schools that DO NOT offer calc. If you have ideas about who to talk to, I’d love to start."']
# ['183,"@JAMESFF9 Personally, I think so. He’s elevates the performance of every player. He’s managed to form a balanced xi despite not having a DM or RW. He’s shored up the defense significantly. He’s made advances in the academy, data science, health depts. All around positive."']
# ['184,"@digitaljamaican @yeknology I think if ""becoming competent"" is someone\'s limiting factor then it\'s a losing battle. 8-12 months of disciplined practice and training can get you pretty good at most digital skills, from video editing to data science."']
# ['185,"@alittlestats @AmeliaMN I think the whole field is super squishy on a definition for data science. As a professional society leader, I’ve been pushing for us to have some good cross-sector convos about this. I don’t want this to be another math-compsci debacle."']
# ['186,"The pandemic exposed the need to think about tomorrow’s supply chains. How do we create resiliency and agility in the digital age? I love this explanation from @NelsonPetracek, @TIBCO CTO, who says the answer lies with data science and digital twins']
# ['https://t.co/9t1p1pDO8z"']
# ['187,"@jscotttn Finally!! I once tried to make a spreadsheet of your narration in the videos to count funny things you say but it took too long!! (Also I stopped after 3 videos I think)As a Data Science student I’d love to analyze them one day ☺️"']
# ['188,"@wayner99 Stats is definitely more useful than I used to think when I started my university journey.']
# ['Now the question is:']
# [' - how much stats can you learn without calculus?']
# [' - what do we add to stats to make it data science? are we implicitly including some compsci / coding there, or ???"']
# ['189,"@mattmoehr I don\'t think it\'s a stretch to say that if statistics and data science were presented as the end goals to me instead of needing to do calculus (which I failed, miserably), my life would look very, very different right now."']
# ['190,"Artificial Intelligence (AI), and Data Science, have become the two most important sought-after technologies in today’s world. Many people think that both are the same, but they are not. Let’s dive deeper into 12 terms you need to know.']
# ['Read: https://t.co/XSaWhVTKGL https://t.co/HQlOaOlQ6O"']
# ['191,"Probably unpopular opinion, but I think it’s great. Basic stats and data science is probably more broadly relevant than calculus these days. Plus it sounds refreshing, and if done well, it will make school much more fun and help with data literacy :) https://t.co/N5jBadxW5O"']
# ['192,"I have given ""What is Data Science?"" talks to high schoolers, and they\'re fascinated by it. I think giving them a taste of what you can do with statistics and data (and what kind of careers require that background) will motivate them to go further with math in college."']
# ['193,"Probably unpopular opinion, but I think it’s great. Basic stats and data science is probably more broadly relevant than calculus these days. Plus it sounds refreshing, and if done well, it will make school much more fun and help with data literacy :) https://t.co/N5jBadxW5O"']
# ...
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['747,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['748,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['749,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['750,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['751,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['752,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['753,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['754,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['755,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['756,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['757,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['758,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['759,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['760,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['761,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['762,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['763,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['764,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['765,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['766,"Truth b told:']
# ["STFC/Sngor had 'HIDE equivalent' Data Analytics capability lot earlier when we've Data Sharing frm MOH. We did Targetted Comm Screening with it."]
# ['STFC urges Govt to think 360° of its Cost-Benefit Analysis esp MITIGATION MEASURES needed! ']
# ['https://t.co/woEdSykCD1"']
# ['767,"@ShaharyarRants Um, you literally use data analytics on football and I think that\'s pretty impressive. That\'s talent"']
# ['768,"""We need to think about the systems that will not only deliver value today, but also evolve and adapt to continue to deliver value as the world changes around us and these systems have to do it automatically because humans cannot keep up"" https://t.co/4Rm5GM3pxV via @CIOdive"']
# ['769,"While there are several potential sources for transportation data, they are not all equal. When selecting a transportation data analytics provider (or any data provider really), we think you should ask these five questions. ']
# ['Learn more here: https://t.co/G6eS5lsFx9"']
# ['770,"Who\'s Your Data...goes global. @kristinluck chats using data to grow &amp; scale companies, her vision for @ESOMAR as president, what it means to think about data ethics on a Global scale and tackling diversity.']
# ['https://t.co/L93bkPVtrf']
# ['#mrx @gbarash11 #data #analytics #marketing"']
# ['771,"Who\'s Your Data...goes global. @kristinluck chats using data to grow &amp; scale companies, her vision for @ESOMAR as president, what it means to think about data ethics on a Global scale and tackling diversity.']
# ['https://t.co/L93bkPVtrf']
# ['#mrx @gbarash11 #data #analytics #marketing"']
# ['772,"Who\'s Your Data...goes global. @kristinluck chats using data to grow &amp; scale companies, her vision for @ESOMAR as president, what it means to think about data ethics on a Global scale and tackling diversity.']
# ['https://t.co/L93bkPVtrf']
# ['#mrx @gbarash11 #data #analytics #marketing"']
# ['773,"@hmason Do you think you’ll have future openings in data analytics? Super excited about your game."']
# ['774,"@descovyschild Bahahaha I think either field will meet that need. From where I’m sitting - very loosely adjacent to both fields in that I support the tech that both use - data analytics seems to be harder to find and fill roles."']
# ['775,"@igneer4 @krystalball It\'s so damn frustrating considering my work is business data analytics and thus literally measure things like how well a message impacts the public and manipulates them.']
# ['It\'s so exhausting to tell people over and over only to think they are the unique exception not impacted."']
# ['776,"How @EU_CLASS project\'s software architecture make smart cities ""think"" in real-time, potentially saving lives?']
# ['If you missed out CLASS webinar last week, you can have your own Friday movie and watch it here: https://t.co/ViotPvtORR 🍿📽️"']
# ['777,"Joshua Frank, CEO of cryptocurrency data analytics to Cointelegraph:']
# ['    “People turn to Dogecoin to show that they can make anything work, even against the odds. I said this many times: I think it’s always 20% about technology, 80% about adoption. And in this case, Doge is"']
# ['778,"Joshua Frank, CEO of cryptocurrency data analytics to Cointelegraph:']
# ['    “People turn to Dogecoin to show that they can make anything work, even against the odds. I said this many times: I think it’s always 20% about technology, 80% about adoption. And in this case, Doge is"']
# ['779,"How @EU_CLASS project\'s software architecture make smart cities ""think"" in real-time, potentially saving lives?']
# ['If you missed out CLASS webinar last week, you can have your own Friday movie and watch it here: https://t.co/ViotPvtORR 🍿📽️"']
# ['780,"How @EU_CLASS project\'s software architecture make smart cities ""think"" in real-time, potentially saving lives?']
# ['If you missed out CLASS webinar last week, you can have your own Friday movie and watch it here: https://t.co/ViotPvtORR 🍿📽️"']
# ['781,"How @EU_CLASS project\'s software architecture make smart cities ""think"" in real-time, potentially saving lives?']
# ['If you missed out CLASS webinar last week, you can have your own Friday movie and watch it here: https://t.co/ViotPvtORR 🍿📽️"']
# ['782,"Will greet if Celtic ever get a player the quality of Lubo again. ']
# ['I think data analytics based scouting makes hidden gems like this more and more difficult to get. (Even if Celtic show no evidence of using it, other clubs will). https://t.co/dr38SOezJn"']
# ['783,"“Can you help me find a systems engineer? I need someone who can do simulation modeling, human factors, write SQL code, do data analytics, lead performance improvement work, and mentor teams.”']
# ['That’s 6 different specialties. I love how MD/RN think any techie can do ALL THE TECH."']
# ['784,"Did you ever feel like drowning in #data 🏊? Highly recommend this article about smart data analytics and AI projects. Learn how to swim in your data lake.']
# ['📰: https://t.co/ei1Aad6ZYs"']
# ['785,"Understanding how stakeholders think and how best to communicate data is crucial.']
# ['The GSW analytics team found that coaches and players did not like terms like ""data"", ""analytics""']
# ['They had to learn how coaches want their data delivered, and how best to convey to them."']
# ['786,"I think some day when I\'m not lazy I\'m going to take some data analytics models and compare their output to astrological transits AND SEE WHAT HAPPENS 😂"']
# ['787,"@equialpha Considering the Future of AI, ML, IOT, Data Analytics, Blockchain...I think Saksoft is still undervalued and have a lot of potential to grow"']
# ['788,"ESG data, Greenwashers, Socialwashers and the new innovations of ESG data. ']
# ['Listen now to our intense podcast on Spotify and iTunes. ']
# ['Tell your boss, I think they need to hear this too!! 🤓🧐😬']
# [' #data #analytics #esg #greenwashing https://t.co/utSKrRHW2N"']
# ['789,"Digital transformation in #banking can\'t occur without #data, #analytics, #AI, and #cloud technology.']
# ['Learn more at #Think2021']
# ['Register today: https://t.co/fUNqGlfZ7y']
# ['#IBMPartner #DigitalTransformation #FinServ #FinTech ']
# ['@DeepLearn007 @ipfconline1 @SpirosMargaris @jowyang https://t.co/orzHvjizT9"']
# ['790,"Digital transformation in #banking can\'t occur without #data, #analytics, #AI, and #cloud technology.']
# ['Learn more at #Think2021']
# ['Register today: https://t.co/fUNqGlfZ7y']
# ['#IBMPartner #DigitalTransformation #FinServ #FinTech ']
# ['@DeepLearn007 @ipfconline1 @SpirosMargaris @jowyang https://t.co/orzHvjizT9"']
# ['791,"For those who think that whipping up a dashboard or data analytics is the solution. Dashboards work only if the underlying basics are fine - healthcare or otherwise. https://t.co/kqdyBuI4T3"']
# ['792,"🤔 Think there is no room for animation in data services? Think again!']
# ['Check out our latest creation for The @ClassificationG! Susan has personality by the bucket load and her business reflects this.']
# ['#procurement #data #analytics #animationstudio https://t.co/7Y2OQQEbgo"']
# ['793,"@EllaMinty @drcraigfleisher @samvonwallace @PaulEllisUK Precisely. this is why I think we will see more R&amp;D and investment to promote the democratization of data analytics and OSINT tech. And that\'s the mosh pit I am in. #PowerAndInfluence"']
# ['794,"@EllaMinty @drcraigfleisher @samvonwallace @PaulEllisUK Precisely. this is why I think we will see more R&amp;D and investment to promote the democratization of data analytics and OSINT tech. And that\'s the mosh pit I am in. #PowerAndInfluence"']
# ['795,"@EllaMinty @drcraigfleisher @samvonwallace @PaulEllisUK Precisely. this is why I think we will see more R&amp;D and investment to promote the democratization of data analytics and OSINT tech. And that\'s the mosh pit I am in. #PowerAndInfluence"']
# ['796,"@EllaMinty @drcraigfleisher @samvonwallace @PaulEllisUK Precisely. this is why I think we will see more R&amp;D and investment to promote the democratization of data analytics and OSINT tech. And that\'s the mosh pit I am in. #PowerAndInfluence"']
# ['797,"@cgduckworth @CoreyAtad @FCardamenis I think the proliferation of data analytics models being taken as gospel in many fields - sports, food, clothing, politics, entertainment - has had a lot of sinister effect on this. More than before, that is."']
# ['798,"@SimonHoiberg For me, it was a career path that would feed my desire to be creative, think critically, and build things that help people. ']
# ["I was on a marketing path, and I really didn't enjoy the data analytics side of things at all. "]
# ['The bump in pay was also a huge factor."']
# ['799,"We think it comes down to 3 C’s: Capability, Cash, and Collaboration!']
# ['Capability? E.g., Event Notifications, eCQM Reporting, #SDOH for social care transformation, data analytics, support for info blocking, integration of behavioral health, public health support https://t.co/hvV8BQUyfx"']
# ['800,"""Stop calling the technology the product. As an industry, we must think in terms of a complete offer which includes technology, services, and data analytics."" Hal Stanley, TSIA, Sr. Director, Service Offer Portfolio Research. #tsiainteract #serviceoffermanagement https://t.co/d6AxWASkbM"']
# ['801,"Digital transformation in #banking can\'t occur without #data, #analytics, #AI, and #cloud technology.']
# ['Learn more at #Think2021']
# ['Register today: https://t.co/fUNqGlfZ7y']
# ['#IBMPartner #DigitalTransformation #FinServ #FinTech ']
# ['@DeepLearn007 @ipfconline1 @SpirosMargaris @jowyang https://t.co/orzHvjizT9"']
# ['802,"@DeanEggitt @Parody_RCGP @DrShanHussain @DrSimonHodes @Dr_Ayan @DrNeenaJha @yvettedoc50 @KailashChandOBE @NikkiKF @CNagpaul @nhsfatcat @PS_Panesar @pkonline84 @BMA_GP @trishgreenhalgh @ClareGerada @rcgp Who do you think will be controlling patient data analytics, deciding on which services get provided and for how long, setting incentives for denial of care?']
# ['ACO designed by insurance industry &amp; providers']
# ['#UnitedHealth #Optum has metastasised throughout #NHS from leadership down."']
# ['803,"@navift @atomcamp @shuakhalid Naveed, this is interesting. I think we should have skills from basic mathematics to Data Analytics &amp; E Commerce. Let me know if there is a focus group discussing these programs and I can chip in!"']
# {}
