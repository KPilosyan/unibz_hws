# %%
import csv
import numpy as np

# %%
# the input data is contained in the dictionary pages_dict
# the key is the index of the src page. for each key there is a further dictionary, 
# containing the degree of the src page and the list of its destinations
#{
#    src1: {"degree":degree1, "destinations": [destinations1]},
#    src2: {"degree":degree2, "destinations": [destinations2]},
#    ...
#    
#}
pages_dict={}

#the pages_dict dictionary is initialised with the contents of the "example_index" file. 
#the "degree" and destinations fields are still empty. they will be filled reading the "example_arcs" file.
with open('example_index') as index_file:                                                                                          
    index_list = csv.reader(index_file, delimiter='\t')
    for index in index_list:
        pages_dict[int(index[1])]={"url":index[0],"degree":0,"destinations":[]}

# %%
# the pages_dict dictionary is updated with the destination information. 
# reading the lines of the "example_arcs" file, for any destination the "degree" field is incremented, 
# and the destination is added to the "destination" list of the relevant element
with open('example_arcs') as arcs_file:                                                                                          
    arclist = csv.reader(arcs_file, delimiter='\t')
    for arc in arclist:
        pages_dict[int(arc[0])]["degree"]+=1
        pages_dict[int(arc[0])]["destinations"].append(int(arc[1]))

# %%
pages_dict
# Out:
# {0: {'url': '1000notes.com', 'degree': 0, 'destinations': []},
#  1: {'url': '100500.tv', 'degree': 0, 'destinations': []},
#  2: {'url': 'abebooks.com', 'degree': 0, 'destinations': []},
#  3: {'url': 'abebooks.de', 'degree': 0, 'destinations': []},
#  4: {'url': 'amazon-presse.de', 'degree': 0, 'destinations': []},
#  5: {'url': 'amazon.ca', 'degree': 0, 'destinations': []},
#  6: {'url': 'amazon.cn', 'degree': 0, 'destinations': []},
#  7: {'url': 'amazon.co.jp',
#   'degree': 10,
#   'destinations': [5, 6, 8, 9, 10, 12, 26, 57, 70, 82]},
#  8: {'url': 'amazon.co.uk', 'degree': 0, 'destinations': []},
#  9: {'url': 'amazon.com',
#   'degree': 25,
#   'destinations': [2,
#    5,
#    6,
#    7,
#    8,
#    10,
#    11,
#    12,
#    13,
#    17,
#    21,
#    27,
#    35,
#    38,
#    41,
#    42,
#    52,
#    70,
#    82,
#    83,
#    84,
#    92,
#    97,
#    103,
#    104]},
#  10: {'url': 'amazon.de',
#   'degree': 16,
#   'destinations': [3, 4, 5, 6, 7, 8, 9, 12, 18, 26, 28, 53, 56, 63, 70, 82]},
#  11: {'url': 'amazon.es', 'degree': 0, 'destinations': []},
#  12: {'url': 'amazon.fr', 'degree': 0, 'destinations': []},
#  13: {'url': 'amazon.it', 'degree': 0, 'destinations': []},
#  14: {'url': 'angrybirds.com', 'degree': 0, 'destinations': []},
#  15: {'url': 'animationplayhouse.com', 'degree': 1, 'destinations': [102]},
#  16: {'url': 'apple.com', 'degree': 0, 'destinations': []},
#  17: {'url': 'audible.com', 'degree': 0, 'destinations': []},
#  18: {'url': 'audible.de', 'degree': 0, 'destinations': []},
#  19: {'url': 'automattic.com', 'degree': 0, 'destinations': []},
#  20: {'url': 'azspot.net', 'degree': 1, 'destinations': [88]},
#  21: {'url': 'beautybar.com', 'degree': 0, 'destinations': []},
#  22: {'url': 'blogalaxia.com', 'degree': 2, 'destinations': [25, 74]},
#  23: {'url': 'blogg.se', 'degree': 0, 'destinations': []},
#  24: {'url': 'blogia.com', 'degree': 1, 'destinations': [25]},
#  25: {'url': 'blogspot.com',
#   'degree': 23,
#   'destinations': [22,
#    23,
#    29,
#    32,
#    43,
#    44,
#    47,
#    48,
#    49,
#    52,
#    60,
#    61,
#    71,
#    72,
#    73,
#    81,
#    88,
#    89,
#    90,
#    95,
#    98,
#    100,
#    102]},
#  26: {'url': 'bookdepository.co.uk', 'degree': 0, 'destinations': []},
#  27: {'url': 'bookdepository.com', 'degree': 0, 'destinations': []},
#  28: {'url': 'buyvip.com', 'degree': 0, 'destinations': []},
#  29: {'url': 'canalblog.com', 'degree': 0, 'destinations': []},
#  30: {'url': 'carambatv.ru', 'degree': 0, 'destinations': []},
#  31: {'url': 'classicalvalues.com', 'degree': 1, 'destinations': [25]},
#  32: {'url': 'creativecommons.org', 'degree': 0, 'destinations': []},
#  33: {'url': 'cubicle17.com', 'degree': 0, 'destinations': []},
#  34: {'url': 'cyprien.fr', 'degree': 0, 'destinations': []},
#  35: {'url': 'diapers.com', 'degree': 0, 'destinations': []},
#  36: {'url': 'disqus.com', 'degree': 0, 'destinations': []},
#  37: {'url': 'downthisvideo.com', 'degree': 1, 'destinations': [48]},
#  38: {'url': 'dpreview.com', 'degree': 0, 'destinations': []},
#  39: {'url': 'drdrum.com', 'degree': 0, 'destinations': []},
#  40: {'url': 'eltangoysusinvitados.com', 'degree': 1, 'destinations': [25]},
#  41: {'url': 'endless.com', 'degree': 0, 'destinations': []},
#  42: {'url': 'fabric.com', 'degree': 0, 'destinations': []},
#  43: {'url': 'facebook.com', 'degree': 0, 'destinations': []},
#  44: {'url': 'flickr.com', 'degree': 3, 'destinations': [16, 45, 100]},
#  45: {'url': 'flickr.net', 'degree': 0, 'destinations': []},
#  46: {'url': 'gmpg.org', 'degree': 0, 'destinations': []},
#  47: {'url': 'goodreads.com', 'degree': 0, 'destinations': []},
#  48: {'url': 'google.com', 'degree': 1, 'destinations': [25]},
#  49: {'url': 'histats.com', 'degree': 0, 'destinations': []},
#  50: {'url': 'hockeyfights.com', 'degree': 0, 'destinations': []},
#  51: {'url': 'icecastles.com', 'degree': 0, 'destinations': []},
#  52: {'url': 'imdb.com', 'degree': 0, 'destinations': []},
#  53: {'url': 'imdb.de', 'degree': 0, 'destinations': []},
#  54: {'url': 'img-dpreview.com', 'degree': 1, 'destinations': [38]},
#  55: {'url': 'instagr.am', 'degree': 0, 'destinations': []},
#  56: {'url': 'javari.de', 'degree': 0, 'destinations': []},
#  57: {'url': 'javari.jp', 'degree': 0, 'destinations': []},
#  58: {'url': 'joblo.com', 'degree': 0, 'destinations': []},
#  59: {'url': 'kenyaunlimited.com', 'degree': 1, 'destinations': [25]},
#  60: {'url': 'linkwithin.com', 'degree': 0, 'destinations': []},
#  61: {'url': 'livejournal.com', 'degree': 0, 'destinations': []},
#  62: {'url': 'lockerz.com', 'degree': 0, 'destinations': []},
#  63: {'url': 'lovefilm.de', 'degree': 0, 'destinations': []},
#  64: {'url': 'memeorandum.com', 'degree': 1, 'destinations': [25]},
#  65: {'url': 'mesvilaweb.cat', 'degree': 1, 'destinations': [25]},
#  66: {'url': 'minecraftforum.net', 'degree': 0, 'destinations': []},
#  67: {'url': 'minimalist.co', 'degree': 0, 'destinations': []},
#  68: {'url': 'moxnews.com', 'degree': 0, 'destinations': []},
#  69: {'url': 'mu.nu', 'degree': 1, 'destinations': [25]},
#  70: {'url': 'myhabit.com', 'degree': 0, 'destinations': []},
#  71: {'url': 'ning.com', 'degree': 0, 'destinations': []},
#  72: {'url': 'nytimes.com', 'degree': 0, 'destinations': []},
#  73: {'url': 'over-blog.com', 'degree': 1, 'destinations': [29]},
#  74: {'url': 'perublogs.com', 'degree': 0, 'destinations': []},
#  75: {'url': 'petervidani.com', 'degree': 0, 'destinations': []},
#  76: {'url': 'pjmedia.com', 'degree': 1, 'destinations': [25]},
#  77: {'url': 'qwika.com', 'degree': 1, 'destinations': [95]},
#  78: {'url': 'rea-group.com', 'degree': 0, 'destinations': []},
#  79: {'url': 'realestate.com.au', 'degree': 1, 'destinations': [78]},
#  80: {'url': 'rivals.com', 'degree': 0, 'destinations': []},
#  81: {'url': 'sapo.pt', 'degree': 1, 'destinations': [25]},
#  82: {'url': 'shopbop.com', 'degree': 0, 'destinations': []},
#  83: {'url': 'smallparts.com', 'degree': 0, 'destinations': []},
#  84: {'url': 'soap.com', 'degree': 0, 'destinations': []},
#  85: {'url': 'spreadshirt.com', 'degree': 0, 'destinations': []},
#  86: {'url': 'technorati.com', 'degree': 0, 'destinations': []},
#  87: {'url': 'tinyurl.com', 'degree': 0, 'destinations': []},
#  88: {'url': 'tumblr.com',
#   'degree': 7,
#   'destinations': [0, 33, 36, 44, 55, 67, 75]},
#  89: {'url': 'twitter.com', 'degree': 0, 'destinations': []},
#  90: {'url': 'typepad.com', 'degree': 3, 'destinations': [25, 86, 98]},
#  91: {'url': 'vodpod.com', 'degree': 1, 'destinations': [62]},
#  92: {'url': 'wag.com', 'degree': 0, 'destinations': []},
#  93: {'url': 'wikidict.de', 'degree': 1, 'destinations': [95]},
#  94: {'url': 'wikimedia.org', 'degree': 0, 'destinations': []},
#  95: {'url': 'wikipedia.org', 'degree': 2, 'destinations': [32, 94]},
#  96: {'url': 'wiktionary.org', 'degree': 1, 'destinations': [32]},
#  97: {'url': 'woot.com', 'degree': 0, 'destinations': []},
#  98: {'url': 'wordpress.com',
#   'degree': 10,
#   'destinations': [19, 25, 44, 46, 89, 90, 91, 95, 99, 102]},
#  99: {'url': 'wordpress.org', 'degree': 0, 'destinations': []},
#  100: {'url': 'yahoo.com', 'degree': 3, 'destinations': [79, 80, 101]},
#  101: {'url': 'yahoo.com.au', 'degree': 0, 'destinations': []},
#  102: {'url': 'youtube.com',
#   'degree': 16,
#   'destinations': [1,
#    14,
#    16,
#    30,
#    34,
#    39,
#    43,
#    48,
#    50,
#    51,
#    58,
#    66,
#    68,
#    85,
#    87,
#    88]},
#  103: {'url': 'yoyo.com', 'degree': 0, 'destinations': []},
#  104: {'url': 'zappos.com', 'degree': 0, 'destinations': []},
#  105: {'url': 'zoomblog.com', 'degree': 1, 'destinations': [25]}}

# %%
# N contains the number of pages
N=len(pages_dict)
print(f"{N} indexes have been read.")

# beta contains the beta factor
beta=0.9
print(f"beta is {beta}")
# Out:
# 106 indexes have been read.
# beta is 0.9

# %%
#the pages_dict structure is printed
print("The following dictionary has been created\n\n")
print("pages_dict={")
for src in pages_dict:
    print()
    print("\t",src,":\t{")
    print("\t\t'url': '",pages_dict[src]["url"],"',")
    print("\t\t'degree':",pages_dict[src]["degree"],",")
    print("\t\t'destinations'",pages_dict[src]["destinations"])
    print("\t\t}")
    print()
print("}")
# Out:
# The following dictionary has been created
#
#
# pages_dict={
#
# 	 0 :	{
# 		'url': ' 1000notes.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 1 :	{
# 		'url': ' 100500.tv ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 2 :	{
# 		'url': ' abebooks.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 3 :	{
# 		'url': ' abebooks.de ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 4 :	{
# 		'url': ' amazon-presse.de ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 5 :	{
# 		'url': ' amazon.ca ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 6 :	{
# 		'url': ' amazon.cn ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 7 :	{
# 		'url': ' amazon.co.jp ',
# 		'degree': 10 ,
# 		'destinations' [5, 6, 8, 9, 10, 12, 26, 57, 70, 82]
# 		}
#
#
# 	 8 :	{
# 		'url': ' amazon.co.uk ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 9 :	{
# 		'url': ' amazon.com ',
# 		'degree': 25 ,
# 		'destinations' [2, 5, 6, 7, 8, 10, 11, 12, 13, 17, 21, 27, 35, 38, 41, 42, 52, 70, 82, 83, 84, 92, 97, 103, 104]
# 		}
#
#
# 	 10 :	{
# 		'url': ' amazon.de ',
# 		'degree': 16 ,
# 		'destinations' [3, 4, 5, 6, 7, 8, 9, 12, 18, 26, 28, 53, 56, 63, 70, 82]
# 		}
#
#
# 	 11 :	{
# 		'url': ' amazon.es ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 12 :	{
# 		'url': ' amazon.fr ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 13 :	{
# 		'url': ' amazon.it ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 14 :	{
# 		'url': ' angrybirds.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 15 :	{
# 		'url': ' animationplayhouse.com ',
# 		'degree': 1 ,
# 		'destinations' [102]
# 		}
#
#
# 	 16 :	{
# 		'url': ' apple.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 17 :	{
# 		'url': ' audible.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 18 :	{
# 		'url': ' audible.de ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 19 :	{
# 		'url': ' automattic.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 20 :	{
# 		'url': ' azspot.net ',
# 		'degree': 1 ,
# 		'destinations' [88]
# 		}
#
#
# 	 21 :	{
# 		'url': ' beautybar.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 22 :	{
# 		'url': ' blogalaxia.com ',
# 		'degree': 2 ,
# 		'destinations' [25, 74]
# 		}
#
#
# 	 23 :	{
# 		'url': ' blogg.se ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 24 :	{
# 		'url': ' blogia.com ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 25 :	{
# 		'url': ' blogspot.com ',
# 		'degree': 23 ,
# 		'destinations' [22, 23, 29, 32, 43, 44, 47, 48, 49, 52, 60, 61, 71, 72, 73, 81, 88, 89, 90, 95, 98, 100, 102]
# 		}
#
#
# 	 26 :	{
# 		'url': ' bookdepository.co.uk ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 27 :	{
# 		'url': ' bookdepository.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 28 :	{
# 		'url': ' buyvip.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 29 :	{
# 		'url': ' canalblog.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 30 :	{
# 		'url': ' carambatv.ru ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 31 :	{
# 		'url': ' classicalvalues.com ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 32 :	{
# 		'url': ' creativecommons.org ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 33 :	{
# 		'url': ' cubicle17.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 34 :	{
# 		'url': ' cyprien.fr ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 35 :	{
# 		'url': ' diapers.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 36 :	{
# 		'url': ' disqus.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 37 :	{
# 		'url': ' downthisvideo.com ',
# 		'degree': 1 ,
# 		'destinations' [48]
# 		}
#
#
# 	 38 :	{
# 		'url': ' dpreview.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 39 :	{
# 		'url': ' drdrum.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 40 :	{
# 		'url': ' eltangoysusinvitados.com ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 41 :	{
# 		'url': ' endless.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 42 :	{
# 		'url': ' fabric.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 43 :	{
# 		'url': ' facebook.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 44 :	{
# 		'url': ' flickr.com ',
# 		'degree': 3 ,
# 		'destinations' [16, 45, 100]
# 		}
#
#
# 	 45 :	{
# 		'url': ' flickr.net ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 46 :	{
# 		'url': ' gmpg.org ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 47 :	{
# 		'url': ' goodreads.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 48 :	{
# 		'url': ' google.com ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 49 :	{
# 		'url': ' histats.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 50 :	{
# 		'url': ' hockeyfights.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 51 :	{
# 		'url': ' icecastles.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 52 :	{
# 		'url': ' imdb.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 53 :	{
# 		'url': ' imdb.de ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 54 :	{
# 		'url': ' img-dpreview.com ',
# 		'degree': 1 ,
# 		'destinations' [38]
# 		}
#
#
# 	 55 :	{
# 		'url': ' instagr.am ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 56 :	{
# 		'url': ' javari.de ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 57 :	{
# 		'url': ' javari.jp ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 58 :	{
# 		'url': ' joblo.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 59 :	{
# 		'url': ' kenyaunlimited.com ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 60 :	{
# 		'url': ' linkwithin.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 61 :	{
# 		'url': ' livejournal.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 62 :	{
# 		'url': ' lockerz.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 63 :	{
# 		'url': ' lovefilm.de ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 64 :	{
# 		'url': ' memeorandum.com ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 65 :	{
# 		'url': ' mesvilaweb.cat ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 66 :	{
# 		'url': ' minecraftforum.net ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 67 :	{
# 		'url': ' minimalist.co ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 68 :	{
# 		'url': ' moxnews.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 69 :	{
# 		'url': ' mu.nu ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 70 :	{
# 		'url': ' myhabit.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 71 :	{
# 		'url': ' ning.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 72 :	{
# 		'url': ' nytimes.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 73 :	{
# 		'url': ' over-blog.com ',
# 		'degree': 1 ,
# 		'destinations' [29]
# 		}
#
#
# 	 74 :	{
# 		'url': ' perublogs.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 75 :	{
# 		'url': ' petervidani.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 76 :	{
# 		'url': ' pjmedia.com ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 77 :	{
# 		'url': ' qwika.com ',
# 		'degree': 1 ,
# 		'destinations' [95]
# 		}
#
#
# 	 78 :	{
# 		'url': ' rea-group.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 79 :	{
# 		'url': ' realestate.com.au ',
# 		'degree': 1 ,
# 		'destinations' [78]
# 		}
#
#
# 	 80 :	{
# 		'url': ' rivals.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 81 :	{
# 		'url': ' sapo.pt ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
#
# 	 82 :	{
# 		'url': ' shopbop.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 83 :	{
# 		'url': ' smallparts.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 84 :	{
# 		'url': ' soap.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 85 :	{
# 		'url': ' spreadshirt.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 86 :	{
# 		'url': ' technorati.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 87 :	{
# 		'url': ' tinyurl.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 88 :	{
# 		'url': ' tumblr.com ',
# 		'degree': 7 ,
# 		'destinations' [0, 33, 36, 44, 55, 67, 75]
# 		}
#
#
# 	 89 :	{
# 		'url': ' twitter.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 90 :	{
# 		'url': ' typepad.com ',
# 		'degree': 3 ,
# 		'destinations' [25, 86, 98]
# 		}
#
#
# 	 91 :	{
# 		'url': ' vodpod.com ',
# 		'degree': 1 ,
# 		'destinations' [62]
# 		}
#
#
# 	 92 :	{
# 		'url': ' wag.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 93 :	{
# 		'url': ' wikidict.de ',
# 		'degree': 1 ,
# 		'destinations' [95]
# 		}
#
#
# 	 94 :	{
# 		'url': ' wikimedia.org ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 95 :	{
# 		'url': ' wikipedia.org ',
# 		'degree': 2 ,
# 		'destinations' [32, 94]
# 		}
#
#
# 	 96 :	{
# 		'url': ' wiktionary.org ',
# 		'degree': 1 ,
# 		'destinations' [32]
# 		}
#
#
# 	 97 :	{
# 		'url': ' woot.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 98 :	{
# 		'url': ' wordpress.com ',
# 		'degree': 10 ,
# 		'destinations' [19, 25, 44, 46, 89, 90, 91, 95, 99, 102]
# 		}
#
#
# 	 99 :	{
# 		'url': ' wordpress.org ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 100 :	{
# 		'url': ' yahoo.com ',
# 		'degree': 3 ,
# 		'destinations' [79, 80, 101]
# 		}
#
#
# 	 101 :	{
# 		'url': ' yahoo.com.au ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 102 :	{
# 		'url': ' youtube.com ',
# 		'degree': 16 ,
# 		'destinations' [1, 14, 16, 30, 34, 39, 43, 48, 50, 51, 58, 66, 68, 85, 87, 88]
# 		}
#
#
# 	 103 :	{
# 		'url': ' yoyo.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 104 :	{
# 		'url': ' zappos.com ',
# 		'degree': 0 ,
# 		'destinations' []
# 		}
#
#
# 	 105 :	{
# 		'url': ' zoomblog.com ',
# 		'degree': 1 ,
# 		'destinations' [25]
# 		}
#
# }

# %%
#r_old is initialised
r_old=np.ones(N)*1/N

# the r vector is calculated by iterations. the iterations are stopped when the maximum relative increment is lower than one part in 10000
for i in range(1000):
    #r_new is initialised for each iteration to include the (1-beta)/N factor
    r_new=np.ones(N)*(1-beta)/N
    #all the src pages are iterated 
    for src in pages_dict:
        #for each src page is taken the degree
        n=pages_dict[src]["degree"]
        
        if n != 0:
            #for each src page is taken the list of the destinations and it is iterated
            for destination in pages_dict[src]["destinations"]:
                #for each destination, the corresponding value of the vector r_new is updated
                r_new[destination]+=beta*r_old[src]/n
    

    if max(abs(r_new-r_old))/r_new.mean() < 0.000001:
        print("Threshold reached after",i,"iterations")
        break
    
    #the iteration is finished and r_old is assigned with the final r_new value for the next iteration
    r_old=r_new
# Out:
# Threshold reached after 18 iterations

# %%
print("Vector R=",r_old)
# Out:
# Vector R= [0.00125959 0.00108378 0.00098292 0.00100397 0.00100397 0.00113741
#  0.00113741 0.00104349 0.00113741 0.00109788 0.00107683 0.00098292
#  0.00113741 0.00098292 0.00108378 0.0009434  0.0016726  0.00098292
#  0.00100397 0.00112014 0.0009434  0.00098292 0.00146983 0.00146983
#  0.0009434  0.01345322 0.00109788 0.00098292 0.00100397 0.00279267
#  0.00108378 0.0009434  0.00382399 0.00125959 0.00108378 0.00098292
#  0.00125959 0.0009434  0.00183198 0.00108378 0.0009434  0.00098292
#  0.00098292 0.00161021 0.00196276 0.00153222 0.00112014 0.00146983
#  0.00245926 0.00146983 0.00108378 0.00108378 0.00150935 0.00100397
#  0.0009434  0.00125959 0.00100397 0.00103731 0.00108378 0.0009434
#  0.00146983 0.00146983 0.00195152 0.00100397 0.0009434  0.0009434
#  0.00108378 0.00125959 0.00108378 0.0009434  0.00113741 0.00146983
#  0.00146983 0.00146983 0.00160482 0.00125959 0.0009434  0.0009434
#  0.00234829 0.00156099 0.00156099 0.00146983 0.00113741 0.00098292
#  0.00098292 0.00108378 0.00143737 0.00108378 0.00245926 0.00164657
#  0.00164657 0.00112014 0.00098292 0.0009434  0.0024485  0.00334468
#  0.0009434  0.00098292 0.0019638  0.00112014 0.00205865 0.00156099
#  0.00249563 0.00098292 0.00098292 0.0009434 ]

# %%
#the pages_dict data structure is update adding the calculated rank to each src page
for i in range(len(r_new)):
    pages_dict[i]["rank"]=r_new[i]

# %%
#the final pages_dict structure is printed
print("The pages dictionary has been updated with the calculated rank\n\n")
print("pages_dict={")
for src in pages_dict:
    print()
    print("\t",src,":\t{")
    print("\t\t'url': '",pages_dict[src]["url"],"',")
    print("\t\t'degree':",pages_dict[src]["degree"],",")
    print("\t\t'destinations'",pages_dict[src]["destinations"],",")
    print("\t\t'rank'",pages_dict[src]["rank"])
    print("\t\t}")
    print()
print("}")
# Out:
# The pages dictionary has been updated with the calculated rank
#
#
# pages_dict={
#
# 	 0 :	{
# 		'url': ' 1000notes.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0012595870815619305
# 		}
#
#
# 	 1 :	{
# 		'url': ' 100500.tv ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 2 :	{
# 		'url': ' abebooks.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 3 :	{
# 		'url': ' abebooks.de ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010039681539167722
# 		}
#
#
# 	 4 :	{
# 		'url': ' amazon-presse.de ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010039681539167722
# 		}
#
#
# 	 5 :	{
# 		'url': ' amazon.ca ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001137406194198178
# 		}
#
#
# 	 6 :	{
# 		'url': ' amazon.cn ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001137406194198178
# 		}
#
#
# 	 7 :	{
# 		'url': ' amazon.co.jp ',
# 		'degree': 10 ,
# 		'destinations' [5, 6, 8, 9, 10, 12, 26, 57, 70, 82] ,
# 		'rank' 0.001043491921282732
# 		}
#
#
# 	 8 :	{
# 		'url': ' amazon.co.uk ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001137406194198178
# 		}
#
#
# 	 9 :	{
# 		'url': ' amazon.com ',
# 		'degree': 25 ,
# 		'destinations' [2, 5, 6, 7, 8, 10, 11, 12, 13, 17, 21, 27, 35, 38, 41, 42, 52, 70, 82, 83, 84, 92, 97, 103, 104] ,
# 		'rank' 0.0010978824268322181
# 		}
#
#
# 	 10 :	{
# 		'url': ' amazon.de ',
# 		'degree': 16 ,
# 		'destinations' [3, 4, 5, 6, 7, 8, 9, 12, 18, 26, 28, 53, 56, 63, 70, 82] ,
# 		'rank' 0.0010768342666965
# 		}
#
#
# 	 11 :	{
# 		'url': ' amazon.es ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 12 :	{
# 		'url': ' amazon.fr ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001137406194198178
# 		}
#
#
# 	 13 :	{
# 		'url': ' amazon.it ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 14 :	{
# 		'url': ' angrybirds.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 15 :	{
# 		'url': ' animationplayhouse.com ',
# 		'degree': 1 ,
# 		'destinations' [102] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 16 :	{
# 		'url': ' apple.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0016726029451902664
# 		}
#
#
# 	 17 :	{
# 		'url': ' audible.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 18 :	{
# 		'url': ' audible.de ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010039681539167722
# 		}
#
#
# 	 19 :	{
# 		'url': ' automattic.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001120137983872867
# 		}
#
#
# 	 20 :	{
# 		'url': ' azspot.net ',
# 		'degree': 1 ,
# 		'destinations' [88] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 21 :	{
# 		'url': ' beautybar.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 22 :	{
# 		'url': ' blogalaxia.com ',
# 		'degree': 2 ,
# 		'destinations' [25, 74] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 23 :	{
# 		'url': ' blogg.se ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 24 :	{
# 		'url': ' blogia.com ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 25 :	{
# 		'url': ' blogspot.com ',
# 		'degree': 23 ,
# 		'destinations' [22, 23, 29, 32, 43, 44, 47, 48, 49, 52, 60, 61, 71, 72, 73, 81, 88, 89, 90, 95, 98, 100, 102] ,
# 		'rank' 0.013453219959334038
# 		}
#
#
# 	 26 :	{
# 		'url': ' bookdepository.co.uk ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010978824268322181
# 		}
#
#
# 	 27 :	{
# 		'url': ' bookdepository.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 28 :	{
# 		'url': ' buyvip.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010039681539167722
# 		}
#
#
# 	 29 :	{
# 		'url': ' canalblog.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.002792670602731891
# 		}
#
#
# 	 30 :	{
# 		'url': ' carambatv.ru ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 31 :	{
# 		'url': ' classicalvalues.com ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 32 :	{
# 		'url': ' creativecommons.org ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0038239899557792187
# 		}
#
#
# 	 33 :	{
# 		'url': ' cubicle17.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0012595870815619305
# 		}
#
#
# 	 34 :	{
# 		'url': ' cyprien.fr ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 35 :	{
# 		'url': ' diapers.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 36 :	{
# 		'url': ' disqus.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0012595870815619305
# 		}
#
#
# 	 37 :	{
# 		'url': ' downthisvideo.com ',
# 		'degree': 1 ,
# 		'destinations' [48] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 38 :	{
# 		'url': ' dpreview.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001831976597554639
# 		}
#
#
# 	 39 :	{
# 		'url': ' drdrum.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 40 :	{
# 		'url': ' eltangoysusinvitados.com ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 41 :	{
# 		'url': ' endless.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 42 :	{
# 		'url': ' fabric.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 43 :	{
# 		'url': ' facebook.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0016102055050710193
# 		}
#
#
# 	 44 :	{
# 		'url': ' flickr.com ',
# 		'degree': 3 ,
# 		'destinations' [16, 45, 100] ,
# 		'rank' 0.0019627592069275572
# 		}
#
#
# 	 45 :	{
# 		'url': ' flickr.net ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0015322240344421948
# 		}
#
#
# 	 46 :	{
# 		'url': ' gmpg.org ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001120137983872867
# 		}
#
#
# 	 47 :	{
# 		'url': ' goodreads.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 48 :	{
# 		'url': ' google.com ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.002459262108844604
# 		}
#
#
# 	 49 :	{
# 		'url': ' histats.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 50 :	{
# 		'url': ' hockeyfights.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 51 :	{
# 		'url': ' icecastles.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 52 :	{
# 		'url': ' imdb.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0015093503616889076
# 		}
#
#
# 	 53 :	{
# 		'url': ' imdb.de ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010039681539167722
# 		}
#
#
# 	 54 :	{
# 		'url': ' img-dpreview.com ',
# 		'degree': 1 ,
# 		'destinations' [38] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 55 :	{
# 		'url': ' instagr.am ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0012595870815619305
# 		}
#
#
# 	 56 :	{
# 		'url': ' javari.de ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010039681539167722
# 		}
#
#
# 	 57 :	{
# 		'url': ' javari.jp ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.00103731049933054
# 		}
#
#
# 	 58 :	{
# 		'url': ' joblo.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 59 :	{
# 		'url': ' kenyaunlimited.com ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 60 :	{
# 		'url': ' linkwithin.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 61 :	{
# 		'url': ' livejournal.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 62 :	{
# 		'url': ' lockerz.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0019515204503526551
# 		}
#
#
# 	 63 :	{
# 		'url': ' lovefilm.de ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010039681539167722
# 		}
#
#
# 	 64 :	{
# 		'url': ' memeorandum.com ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 65 :	{
# 		'url': ' mesvilaweb.cat ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 66 :	{
# 		'url': ' minecraftforum.net ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 67 :	{
# 		'url': ' minimalist.co ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0012595870815619305
# 		}
#
#
# 	 68 :	{
# 		'url': ' moxnews.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 69 :	{
# 		'url': ' mu.nu ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 70 :	{
# 		'url': ' myhabit.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001137406194198178
# 		}
#
#
# 	 71 :	{
# 		'url': ' ning.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 72 :	{
# 		'url': ' nytimes.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 73 :	{
# 		'url': ' over-blog.com ',
# 		'degree': 1 ,
# 		'destinations' [29] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 74 :	{
# 		'url': ' perublogs.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0016048182306195658
# 		}
#
#
# 	 75 :	{
# 		'url': ' petervidani.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0012595870815619305
# 		}
#
#
# 	 76 :	{
# 		'url': ' pjmedia.com ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 77 :	{
# 		'url': ' qwika.com ',
# 		'degree': 1 ,
# 		'destinations' [95] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 78 :	{
# 		'url': ' rea-group.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.002348289718725813
# 		}
#
#
# 	 79 :	{
# 		'url': ' realestate.com.au ',
# 		'degree': 1 ,
# 		'destinations' [78] ,
# 		'rank' 0.00156099260687955
# 		}
#
#
# 	 80 :	{
# 		'url': ' rivals.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.00156099260687955
# 		}
#
#
# 	 81 :	{
# 		'url': ' sapo.pt ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0014698265943229477
# 		}
#
#
# 	 82 :	{
# 		'url': ' shopbop.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001137406194198178
# 		}
#
#
# 	 83 :	{
# 		'url': ' smallparts.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 84 :	{
# 		'url': ' soap.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 85 :	{
# 		'url': ' spreadshirt.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 86 :	{
# 		'url': ' technorati.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0014373667692727339
# 		}
#
#
# 	 87 :	{
# 		'url': ' tinyurl.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0010837751371631657
# 		}
#
#
# 	 88 :	{
# 		'url': ' tumblr.com ',
# 		'degree': 7 ,
# 		'destinations' [0, 33, 36, 44, 55, 67, 75] ,
# 		'rank' 0.002459262108844604
# 		}
#
#
# 	 89 :	{
# 		'url': ' twitter.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0016465683517807206
# 		}
#
#
# 	 90 :	{
# 		'url': ' typepad.com ',
# 		'degree': 3 ,
# 		'destinations' [25, 86, 98] ,
# 		'rank' 0.0016465683517807206
# 		}
#
#
# 	 91 :	{
# 		'url': ' vodpod.com ',
# 		'degree': 1 ,
# 		'destinations' [62] ,
# 		'rank' 0.001120137983872867
# 		}
#
#
# 	 92 :	{
# 		'url': ' wag.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 93 :	{
# 		'url': ' wikidict.de ',
# 		'degree': 1 ,
# 		'destinations' [95] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 94 :	{
# 		'url': ' wikimedia.org ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.0024485029840977802
# 		}
#
#
# 	 95 :	{
# 		'url': ' wikipedia.org ',
# 		'degree': 2 ,
# 		'destinations' [32, 94] ,
# 		'rank' 0.0033446815593278904
# 		}
#
#
# 	 96 :	{
# 		'url': ' wiktionary.org ',
# 		'degree': 1 ,
# 		'destinations' [32] ,
# 		'rank' 0.0009433962264150941
# 		}
#
#
# 	 97 :	{
# 		'url': ' woot.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 98 :	{
# 		'url': ' wordpress.com ',
# 		'degree': 10 ,
# 		'destinations' [19, 25, 44, 46, 89, 90, 91, 95, 99, 102] ,
# 		'rank' 0.0019637971371805874
# 		}
#
#
# 	 99 :	{
# 		'url': ' wordpress.org ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.001120137983872867
# 		}
#
#
# 	 100 :	{
# 		'url': ' yahoo.com ',
# 		'degree': 3 ,
# 		'destinations' [79, 80, 101] ,
# 		'rank' 0.0020586544023500483
# 		}
#
#
# 	 101 :	{
# 		'url': ' yahoo.com.au ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.00156099260687955
# 		}
#
#
# 	 102 :	{
# 		'url': ' youtube.com ',
# 		'degree': 16 ,
# 		'destinations' [1, 14, 16, 30, 34, 39, 43, 48, 50, 51, 58, 66, 68, 85, 87, 88] ,
# 		'rank' 0.0024956249555543055
# 		}
#
#
# 	 103 :	{
# 		'url': ' yoyo.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 104 :	{
# 		'url': ' zappos.com ',
# 		'degree': 0 ,
# 		'destinations' [] ,
# 		'rank' 0.000982919993781054
# 		}
#
#
# 	 105 :	{
# 		'url': ' zoomblog.com ',
# 		'degree': 1 ,
# 		'destinations' [25] ,
# 		'rank' 0.0009433962264150941
# 		}
#
# }

# %%
s = 0
for i in range(106):
    s += pages_dict[i]['rank']

# %%
s
# Out:
# 0.1515222914450789
